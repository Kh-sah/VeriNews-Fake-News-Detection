# %%
import pandas as pd

df = pd.read_csv("../data/news_dataset.csv")

print(df.shape)
df.head()
# Out:
# (44898, 5)
#                                                title  \
# 0  Russian submarines fire cruise missiles at Isl...
# 1   Fox & Friends Ignores FBI Director’s Trump Bo...
# 2  Serbia extradites Kurdish activist to Turkey d...
# 3  THE VIDEO HILLARY CLINTON Does NOT Want You To...
# 4  Illinois governor signs higher education stopg...
#
#                                                 text       subject  \
# 0  MOSCOW (Reuters) - The Russian Navy on Thursda...     worldnews
# 1  Fox & Friends continues to embarrass themselve...          News
# 2  BELGRADE (Reuters) - Serbia has extradited to ...     worldnews
# 3                           Spread this EVERYWHERE!      left-news
# 4  CHICAGO (Reuters) - Illinois Governor Bruce Ra...  politicsNews
#
#                   date  label
# 0  September 14, 2017       1
# 1       March 21, 2017      0
# 2   December 26, 2017       1
# 3          Mar 9, 2016      0
# 4      April 25, 2016       1

# %%
import re
import nltk
from nltk.corpus import stopwords

nltk.download("stopwords")
stop_words = set(stopwords.words("english"))
print("Libraries ready!")
# Out:
# Libraries ready!
# [nltk_data] Downloading package stopwords to C:\Users\Sumit
# [nltk_data]     Kumar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop_words = set(stopwords.words("english"))

def clean_text(text):
    # Convert to lowercase
    text = text.lower()
    
    # Remove punctuation and special characters
    text = re.sub(r"[^a-zA-Z]", " ", text)
    
    # Remove extra spaces
    text = re.sub(r"\s+", " ", text).strip()
    
    # Remove stopwords
    words = text.split()
    words = [word for word in words if word not in stop_words]
    
    return " ".join(words)

# %%
df["clean_text"] = df["text"].apply(clean_text)

# %%
print("Original text:\n", df["text"][0][:500])
print("\nCleaned text:\n", df["clean_text"][0][:500])
# Out:
# Original text:
#  MOSCOW (Reuters) - The Russian Navy on Thursday fired seven cruise missiles at Islamic state targets in the suburbs of Syria s Deir al-Zor, the Russian Defence Ministry said in a statement on Thursday. It said the missiles were fired from two submarines in the eastern Mediterranean from a distance of 500-670 kilometers (727 miles).   The targets were command posts, communication centers, as well as militants  weapons and ammunition stockpiles in areas of south-east Deir al-Zor under the control
#
# Cleaned text:
#  moscow reuters russian navy thursday fired seven cruise missiles islamic state targets suburbs syria deir al zor russian defence ministry said statement thursday said missiles fired two submarines eastern mediterranean distance kilometers miles targets command posts communication centers well militants weapons ammunition stockpiles areas south east deir al zor control islamic state ministry said

# %%
df.to_csv("../data/news_dataset_clean.csv", index=False)
print("Clean dataset saved successfully!")
# Out:
# Clean dataset saved successfully!
